# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import time

import ibdloader
import baseheuristic as bh

rng = np.random.default_rng(2023)

datapath = "../datasets-genotek/"

# %%
#dataset 1: 
#only pure population samples and total ibd length and count between them

#CR_graph_rel.csv
#node_id1,node_id2,label_id1,label_id2,ibd_sum,ibd_n
#node_0,node_5,мордвины,мордвины,29.8172,4

#NC_graph_rel.csv 
#node_id1,node_id2,label_id1,label_id2,ibd_sum,ibd_n
#node_0,node_1,чеченцы,чеченцы,9.76537,1
#node_1,node_138,чеченцы,"кабардинцы,черкесы,адыгейцы",8.01344,1

dataset1fname = datapath+"Scandinavia_weights_partial_labels.csv"
#df = pd.read_csv(dataset1fname)
#print(df)

pairs, weights, labels, labeldict, idxtranslator =\
ibdloader.load_pure( dataset1fname, minclassize = 190, removeclasses=['Russians', 'Tatars,Volga-Tatars,Mishar-Tatars,Kryashens',
                                                             'English'] )


#todo    
    #0. filter out populations with less than N individuals
    #1. select 3 best features and add mixed classifier
    #2. distribution of links between in inside classes    
    #2. use other datasets
    #3. apply neuronet
    #4. also need to compose different graphs for different partitions for future training
    #correct simulator

#data struсture conventions:
#node indices in datasets are not necessarily starting from 0 and consecutive 
#so they are enumerated in idxtranslator.
#for every idx the label of node with index idxtranslator[idx] is stored in labels[idx]
#length of both arrays labels and idxtranslator coincides with count of available nodes in the dataset  

#in graphs we store consecutive labels starting from 0
#it can be even subset of idxtranslator, so every graph must have its own gr_idxtranslator
#and possibly gr_labels

#example
#idxtranslator = [0 1 3 5 10]
#       labels = [2 0 2 0 2]
# pairs = [0 10 100]
#         [1 5 100]
#         [3 10 100]
#subset after removing node_3
#idxtranslator = [0 1 5 10]
#       labels = [2 0 0 2]

#lets not produce translated pairs
#just graphs with corresponding edges and nodes from 0 and consecutive
# Out:
# dropping Russians
# dropping Tatars,Volga-Tatars,Mishar-Tatars,Kryashens
# dropping English
# Unique ids in ibd datafile: 2860
# WARNING: ids are starting from 2 must be translated!
# WARNING: ids are not consequtive, must be translated!
# Filter out all classes smaller than  190
# Removing following classes:
# Sephardim 1
# Puerto-Ricans 1
# Tamils 1
# Evenks 1
# Pashtuns 1
# Mexicans 1
# Ossetians 1
# Czechs,Slovaks 1
# Kyrgyz 1
# Siberian-Tatars 1
# Kumyks 1
# Jews-Azerbaijani 1
# Uzbeks 1
# Chechens 1
# South-Italy 1
# Armenians,Hemshins 2
# Azerbaijanis,Iranians,Turks,Yazidis 2
# Kazakhs 2
# Albanians,Greeks 2
# Ket 3
# Moldovans 3
# Basques 3
# Spaniards 3
# Roma 4
# Balkan 5
# Kabardians,Cherkess,Adygeans 6
# Mari 7
# Khanty,Mansi 8
# Tuscans 8
# Poles 8
# Udmurts,Besermyan 9
# Scots 11
# Dolgans,Yakuts 11
# Mordvins 14
# Komi 15
# Sami 20
# French 21
# Irish 26
# Estonians 28
# Belarusians 33
# Ukrainians 40
# Lithuanians 47
# Bashkirs 55
# Belgium 57
# Karelians,Veps 60
# Chuvash 87
# Germans 126
# Ashkenazim 178
# Total 919 removed
# Remaining classes:
# Danes 190
# Swedes 378
# Norwegians 519
# Finns 854
# dropping Estonians
# dropping Dolgans,Yakuts
# dropping Kazakhs
# dropping Udmurts,Besermyan
# dropping Uzbeks
# dropping Ket
# dropping Mordvins
# dropping Bashkirs
# dropping Kabardians,Cherkess,Adygeans
# dropping Kyrgyz
# dropping Karelians,Veps
# dropping Belarusians
# dropping Ukrainians
# dropping Chuvash
# dropping Komi
# dropping Moldovans
# dropping Evenks
# dropping Ashkenazim
# dropping Basques
# dropping Balkan
# dropping Germans
# dropping Armenians,Hemshins
# dropping French
# dropping Sephardim
# dropping Albanians,Greeks
# dropping Scots
# dropping Puerto-Ricans
# dropping Spaniards
# dropping Tamils
# dropping Pashtuns
# dropping Khanty,Mansi
# dropping Mexicans
# dropping Ossetians
# dropping Lithuanians
# dropping Siberian-Tatars
# dropping Sami
# dropping Czechs,Slovaks
# dropping South-Italy
# dropping Tuscans
# dropping Belgium
# dropping Irish
# dropping Kumyks
# dropping Mari
# dropping Jews-Azerbaijani
# dropping Azerbaijanis,Iranians,Turks,Yazidis
# dropping Chechens
# dropping Poles
# dropping Roma
# Unique ids in ibd datafile: 1940
# WARNING: ids are starting from 1799 must be translated!
# WARNING: ids are not consequtive, must be translated!
# Label dictionary: {'Finns': 0, 'Norwegians': 1, 'Swedes': 2, 'Danes': 3}
# paircount: 29989, unique: 29989
# OK: all pairs are unique

# %% [markdown]
# # 1. построим распределение суммарных весов и количества ibd-сегментов

# %%
print(weights[:,0])
bh.plot_distribution(weights[:,0], 50, "Distribution of ibd sum")
bh.plot_distribution(weights[:,1], 50, "Distribution of ibd max")
bh.plot_distribution(pairs[:,2], 10, "Distribution of ibd count")
# Out:
# [18.2596   8.35242  9.57823 ... 10.7209  15.1966  17.8481 ]
# Distribution of ibd sum
# Total values: 29989 min: 8.00003 max: 281.276 ave: 13.55298217579779
# filtered values: 29691 min: 8.00003 max: 49.965 ave: 12.907493337038161
# Distribution of ibd max
# Total values: 29989 min: 8.00002 max: 82.199 ave: 10.75311837940578
# filtered values: 29978 min: 8.00002 max: 49.903 ave: 10.734079220761892
# Distribution of ibd count
# Total values: 29989 min: 1 max: 24 ave: 1.3430257761179099
# filtered values: 29972 min: 1 max: 9 ave: 1.3362471640197517

# %% [markdown]
# # 2. Распределение весов внутри и между классами

# %%
#change plot_distr to true to plot distributions
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
graphdata = bh.composegraphs(pairs, weights, labels, labeldict, idxtranslator)
ncls = graphdata[0]['nodeclasses']
grph = graphdata[0]['graph']
trns = graphdata[0]['translation']

bh.checkpartition(grph, ncls, None, None, details=True, trns=trns)

weimatrix, countmatrix, distrs = bh.getweightandcountmatrices(grph, ncls, labeldict, plot_distr=False)
# Out:
# Partition is ok, no dangling nodes found

# %%
for dst in distrs:
    print(dst)

# %%
#Optional: fit distributions to popular pdf curves
#distributions here are of ibd sum from individual of one class to the whole another class, so they are
#not symmetric, e.g. distribution from mordvins to belarussians is not the same as distribution from belarussians to mordvins

#it is isteresting to see symmetric distribution as well (distribution on ibd-sum of one link between two classes)
#or distribution of link count from individual of one population to the whole another population (also non-symmetrical)

#total distribution of link count between two individuals is not informative (almost constant 1)


#dist_names = ['alpha', 'gamma', 'norm']
dist_names = ['gamma', 'norm']
for label in distrs:
    #label = "южные-русские"
    data = distrs[label]["data"]
    threshold = distrs[label]["threshold"]
    if threshold is None:
        threshold = 1000
    bins = distrs[label]["bins"]
    bh.plot_and_fit_distribution(data, threshold, bins, f"Distribution of ibd sum for {label}", dist_names)

# %% [markdown]
# # 3. Матрица сумм весов внутри и между классами

# %%
#check total ibd sum between classes
for label in ncls:
    print (f"{label}: {ncls[label].shape[0]}")
    
# в тысячах
cm_display = ConfusionMatrixDisplay(weimatrix, display_labels=labeldict.keys()).plot()
cm_display.ax_.set_title("Веса/1000")
plt.show()
cm_display = ConfusionMatrixDisplay(countmatrix, display_labels=labeldict.keys()).plot()
cm_display.ax_.set_title("Количество ребер")
plt.show()
# Out:
# Finns: 854
# Norwegians: 519
# Swedes: 377
# Danes: 190

# %% [markdown]
# # Классификация
#
# Построим матрицы ошибок по:
#
# 1. количеству ребер до известных классов
# 2. числу ребер на количество членов класса
# 3. количеству ibd-сегментов до известных классов
# 4. самому длинный сегмент
# 5. весу на ребро
# 6. суммарному весу ребер до известных классов

# %%
start = time.time()
featuredict = bh.getfeatures(grph, grph.nodes, ncls, labeldict, pairs, trns )
print(f"features collected in {time.time()-start} seconds\n")
# Out:
# features collected in 283.6036717891693 seconds

# %%
simplepredictions = bh.getsimplepred(featuredict)
for feature in featuredict:
    prediction = simplepredictions[feature]
    title = featuredict[feature]["comment"]
    bh.show_prediction(labels, prediction, labeldict.keys(), title)

# %% [markdown]
# # Наиболее уверенный классификатор

# %%
#наиболее уверенный классификатор среди нескольких с весами
#nodecount = labels.shape[0]
#labelcount = len(labeldict)


featureweights = {
    "SegmentCount": 0,
    "SegmentCountPerClassize": 0,
    "SegmentCountWMult": 1,
    "LongestIbd": 1,
    "IbdSum": 1,
    "IbdSumPerEdge": 0
}

#this is useful for the case where no second-best class is available, so several classifiers have infinite confidence
featurepriority = [
    "IbdSum",
    "LongestIbd",
    "SegmentCountWMult",
    "SegmentCountPerClassize",    
    "SegmentCount",    
    "IbdSumPerEdge"]

mostconfident = bh.get_most_confident_prediction(featuredict, featureweights, featurepriority)
bh.show_prediction(labels, mostconfident, labeldict.keys(), "Классификация наиболее уверенным классификатором.")

# %% [markdown]
# # Простой перебор для поиска наилучшей комбинации весов

# %%
#search for the best parameter combination
#may take hours
featureweightrange = {
    "SegmentCount": [0],
    "SegmentCountPerClassize": np.arange(0.5,1.5,0.1),
    "SegmentCountWMult": [0],    
    "LongestIbd": [1],
    "IbdSum": np.arange(0.1,1.5,0.1),    
    "IbdSumPerEdge": [0]
}

bestweights, bestaccuracy = bh.search_best_weights(featuredict, featureweightrange, featurepriority, labels, trainnodes = None, show_intermediate = False)
print(bestweights, bestaccuracy)
mostconfident = bh.get_most_confident_prediction(featuredict, bestweights, featurepriority)
bh.show_prediction(labels, mostconfident, labeldict.keys(), "Классификация наиболее уверенным классификатором.")

# %% [markdown]
# # Разбиение на "тренировочную", "валидационную" и "тестовую" части

# %% [markdown]
# Разделим каждый класс train:val:test = 60:20:20, веса выберем по "тренировочной"+"валидационной" выборке, метрики посчитаем по "тестовой"

# %%
valshare = 0.2
testshare = 0.2
#print(ncls)
#remember that ncls are starting from 0 and consecutive
#also somewhere we should check connectivity, e.g. if test node have connections with train tree at all

permt = bh.getrandompermutation(ncls, rng)
#print(permt)
trainnodeclasses, valnodeclasses, testnodeclasses = bh.dividetrainvaltest(ncls, valshare, testshare, permt)
#here subdivision does not change translation array as we still have the same graph,
#but will compute features only for test nodes and based on links to trainnodeclasses only
trainvalnodeclasses = {}
for c in trainnodeclasses:
    trainvalnodeclasses[c] = np.concatenate((trainnodeclasses[c], valnodeclasses[c]))

print("train|val|test distribution")
for c in trainnodeclasses:
    print(c, ":", trainnodeclasses[c].shape[0], ":", valnodeclasses[c].shape[0], ":", testnodeclasses[c].shape[0])
    #print(c, ":", trainnodeclasses[c], ":", valnodeclasses[c], ":", testnodeclasses[c])


bh.checkpartition(grph, trainnodeclasses, valnodeclasses, testnodeclasses, details=True, trns=trns)

    
trainnodes, valnodes, testnodes = bh.gettrainvaltestnodes(trainnodeclasses, valnodeclasses, testnodeclasses)
print("train nodes:", trainnodes.shape[0])
print("val nodes:", valnodes.shape[0])
print("test nodes:", testnodes.shape[0])

testlabels = labels[testnodes]

start = time.time()
#featuredict = bh.getfeatures(grph, testnodes, trainnodeclasses, labeldict, pairs, trns )
featuredict = bh.getfeatures(grph, grph.nodes, trainvalnodeclasses, labeldict, pairs, trns )
print(f"features collected in {time.time()-start} seconds\n")

simplepredictions = bh.getsimplepred(featuredict)
for feature in featuredict:
    prediction = simplepredictions[feature]
    #predictedlabels = np.array([ prediction[node] for node in testnodes])
    predictedlabels = prediction[testnodes]
    title = featuredict[feature]["comment"]
    bh.show_prediction(testlabels, predictedlabels, labeldict.keys(), title)
# Out:
# train|val|test distribution
# Estonians : 22 : 8 : 7
# Dolgans,Yakuts : 65 : 22 : 22
# Buryats,Hamnigan,Mongols : 29 : 9 : 10
# Kazakhs : 66 : 22 : 22
# Udmurts,Besermyan : 55 : 18 : 18
# Uzbeks : 11 : 4 : 4
# Tatars,Volga-Tatars,Mishar-Tatars,Kryashens : 701 : 234 : 234
# Ket : 5 : 1 : 2
# Mordvins : 40 : 14 : 13
# Bashkirs : 290 : 96 : 97
# Kabardians,Cherkess,Adygeans : 19 : 6 : 6
# Kyrgyz : 19 : 6 : 6
# Abkhazians,Georgians,Mingrelians : 7 : 3 : 2
# Karelians,Veps : 37 : 12 : 12
# Belarusians : 114 : 38 : 38
# Ukrainians : 118 : 39 : 39
# Chuvash : 200 : 67 : 67
# Komi : 25 : 8 : 8
# Moldovans : 5 : 2 : 2
# Khanty,Mansi : 28 : 10 : 9
# Karachays,Balkars : 14 : 5 : 5
# Tuvans : 2 : 1 : 1
# Nganasan : 2 : 1 : 1
# Chelkans,Shors,Tubalar : 6 : 2 : 2
# Evenks : 2 : 1 : 1
# English : 36 : 12 : 12
# Ashkenazim : 107 : 36 : 36
# Swedes : 114 : 38 : 38
# Balkan : 18 : 6 : 6
# Germans : 118 : 39 : 39
# Armenians,Hemshins : 13 : 5 : 4
# Dagestan : 7 : 2 : 2
# French : 8 : 2 : 3
# Finns : 510 : 170 : 170
# Albanians,Greeks : 4 : 1 : 1
# Spaniards : 1 : 0 : 0
# Hazaras : 1 : 0 : 0
# Pashtuns : 1 : 0 : 0
# Mozabite : 1 : 0 : 0
# Ingush : 9 : 3 : 3
# Jews-Iranian : 1 : 0 : 0
# Karakalpacs : 3 : 1 : 1
# Altaian,Altayans,Khakas,Kachins : 1 : 0 : 0
# Kosovars : 1 : 0 : 0
# Lithuanians : 130 : 43 : 43
# Mexicans : 1 : 0 : 0
# Nogais : 9 : 3 : 3
# Norwegians : 40 : 13 : 13
# Evens : 2 : 1 : 1
# Ossetians : 10 : 4 : 3
# Siberian-Tatars : 9 : 3 : 3
# Sami : 10 : 4 : 3
# Czechs,Slovaks : 4 : 1 : 1
# Tuscans : 4 : 2 : 1
# South-Italy : 3 : 1 : 1
# Danes : 10 : 4 : 3
# Belgium : 5 : 1 : 2
# Irish : 1 : 0 : 0
# Kalmyks : 2 : 1 : 1
# Kumyks : 1 : 1 : 0
# Mari : 29 : 10 : 10
# Russians : 609 : 203 : 203
# Chechens : 11 : 4 : 4
# Azerbaijanis,Iranians,Turks,Yazidis : 5 : 1 : 2
# Korean : 1 : 1 : 0
# Jews-Georgian : 1 : 0 : 0
# Jews-Azerbaijani : 3 : 1 : 1
# Poles : 35 : 11 : 12
# Dangling train node from population Estonians: 13, original id:16
# Dangling train node from population Dolgans,Yakuts: 4327, original id:14510
# Dangling train node from population Dolgans,Yakuts: 3429, original id:13024
# Dangling train node from population Dolgans,Yakuts: 5097, original id:15799
# Dangling train node from population Dolgans,Yakuts: 5118, original id:15831
# Dangling train node from population Dolgans,Yakuts: 4022, original id:14017
# Dangling train node from population Buryats,Hamnigan,Mongols: 43, original id:102
# Dangling train node from population Buryats,Hamnigan,Mongols: 5155, original id:15907
# Dangling train node from population Buryats,Hamnigan,Mongols: 471, original id:2665
# Dangling train node from population Buryats,Hamnigan,Mongols: 5134, original id:15870
# Dangling train node from population Kazakhs: 3900, original id:13800
# Dangling train node from population Kazakhs: 3759, original id:13578
# Dangling train node from population Kazakhs: 39, original id:87
# Dangling train node from population Kazakhs: 4070, original id:14102
# Dangling train node from population Kazakhs: 5131, original id:15860
# Dangling train node from population Uzbeks: 2222, original id:8049
# Dangling train node from population Ket: 95, original id:238
# Dangling train node from population Kabardians,Cherkess,Adygeans: 262, original id:549
# Dangling train node from population Kabardians,Cherkess,Adygeans: 148, original id:363
# Dangling train node from population Abkhazians,Georgians,Mingrelians: 3652, original id:13414
# Dangling train node from population Abkhazians,Georgians,Mingrelians: 152, original id:391
# Dangling train node from population Abkhazians,Georgians,Mingrelians: 154, original id:396
# Dangling train node from population Abkhazians,Georgians,Mingrelians: 3255, original id:12451
# Dangling train node from population Abkhazians,Georgians,Mingrelians: 150, original id:381
# Dangling train node from population Belarusians: 3645, original id:13403
# Dangling train node from population Belarusians: 4185, original id:14284
# Dangling train node from population Belarusians: 5697, original id:16707
# Dangling train node from population Belarusians: 179, original id:432
# Dangling train node from population Belarusians: 5330, original id:16303
# Dangling train node from population Belarusians: 4678, original id:15105
# Dangling train node from population Ukrainians: 5333, original id:16306
# Dangling train node from population Ukrainians: 180, original id:433
# Dangling train node from population Ukrainians: 2220, original id:8040
# Dangling train node from population Ukrainians: 203, original id:460
# Dangling train node from population Ukrainians: 186, original id:440
# Dangling train node from population Ukrainians: 4709, original id:15159
# Dangling train node from population Ukrainians: 4339, original id:14529
# Dangling train node from population Ukrainians: 3520, original id:13179
# Dangling train node from population Khanty,Mansi: 1299, original id:6329
# Dangling train node from population Karachays,Balkars: 4045, original id:14057
# Dangling train node from population Karachays,Balkars: 298, original id:688
# Dangling train node from population Karachays,Balkars: 4638, original id:15042
# Dangling train node from population Evenks: 304, original id:736
# Dangling train node from population English: 322, original id:1466
# Dangling train node from population English: 3147, original id:11416
# Dangling train node from population English: 1291, original id:6283
# Dangling train node from population English: 3240, original id:12097
# Dangling train node from population English: 307, original id:829
# Dangling train node from population English: 330, original id:1647
# Dangling train node from population English: 317, original id:1243
# Dangling train node from population Ashkenazim: 4975, original id:15587
# Dangling train node from population Ashkenazim: 4139, original id:14218
# Dangling train node from population Ashkenazim: 320, original id:1280
# Dangling train node from population Ashkenazim: 4652, original id:15064
# Dangling train node from population Ashkenazim: 602, original id:2825
# Dangling train node from population Ashkenazim: 4942, original id:15529
# Dangling train node from population Ashkenazim: 5227, original id:16038
# Dangling train node from population Ashkenazim: 4217, original id:14329
# Dangling train node from population Ashkenazim: 3530, original id:13191
# Dangling train node from population Ashkenazim: 4973, original id:15582
# Dangling train node from population Ashkenazim: 4899, original id:15450
# Dangling train node from population Ashkenazim: 4936, original id:15516
# Dangling train node from population Ashkenazim: 3639, original id:13395
# Dangling train node from population Ashkenazim: 5143, original id:15887
# Dangling train node from population Ashkenazim: 5140, original id:15883
# Dangling train node from population Ashkenazim: 4554, original id:14890
# Dangling train node from population Ashkenazim: 3742, original id:13548
# Dangling train node from population Ashkenazim: 4310, original id:14485
# Dangling train node from population Ashkenazim: 5172, original id:15941
# Dangling train node from population Ashkenazim: 4529, original id:14854
# Dangling train node from population Ashkenazim: 5079, original id:15770
# Dangling train node from population Ashkenazim: 4029, original id:14027
# Dangling train node from population Ashkenazim: 4969, original id:15575
# Dangling train node from population Ashkenazim: 4043, original id:14054
# Dangling train node from population Ashkenazim: 4221, original id:14338
# Dangling train node from population Ashkenazim: 4036, original id:14040
# Dangling train node from population Swedes: 338, original id:1809
# Dangling train node from population Swedes: 343, original id:1822
# Dangling train node from population Swedes: 365, original id:1865
# Dangling train node from population Swedes: 373, original id:1883
# Dangling train node from population Swedes: 3184, original id:11559
# Dangling train node from population Swedes: 2964, original id:8920
# Dangling train node from population Swedes: 3213, original id:11628
# Dangling train node from population Swedes: 344, original id:1825
# Dangling train node from population Swedes: 2918, original id:8828
# Dangling train node from population Swedes: 3161, original id:11517
# Dangling train node from population Swedes: 3204, original id:11602
# Dangling train node from population Swedes: 2948, original id:8895
# Dangling train node from population Swedes: 3046, original id:9903
# Dangling train node from population Balkan: 1316, original id:6381
# Dangling train node from population Germans: 758, original id:5119
# Dangling train node from population Germans: 760, original id:5126
# Dangling train node from population Germans: 3027, original id:9402
# Dangling train node from population Germans: 3095, original id:11042
# Dangling train node from population Germans: 1218, original id:5933
# Dangling train node from population Germans: 3112, original id:11091
# Dangling train node from population Germans: 1166, original id:5699
# Dangling train node from population Germans: 444, original id:2040
# Dangling train node from population Germans: 1210, original id:5912
# Dangling train node from population Germans: 3114, original id:11097
# Dangling train node from population Germans: 3113, original id:11092
# Dangling train node from population Germans: 1246, original id:6030
# Dangling train node from population Germans: 1175, original id:5761
# Dangling train node from population Germans: 3105, original id:11073
# Dangling train node from population Germans: 1209, original id:5911
# Dangling train node from population Germans: 3132, original id:11192
# Dangling train node from population Germans: 738, original id:4995
# Dangling train node from population Germans: 1192, original id:5853
# Dangling train node from population Germans: 3243, original id:12126
# Dangling train node from population Germans: 1217, original id:5929
# Dangling train node from population Armenians,Hemshins: 4518, original id:14834
# Dangling train node from population Armenians,Hemshins: 5077, original id:15764
# Dangling train node from population Armenians,Hemshins: 4208, original id:14318
# Dangling train node from population Dagestan: 3446, original id:13050
# Dangling train node from population Dagestan: 5000, original id:15633
# Dangling train node from population Finns: 706, original id:3080
# Dangling train node from population Ingush: 3998, original id:13971
# Dangling train node from population Ingush: 727, original id:4896
# Dangling train node from population Karakalpacs: 1143, original id:5528
# Dangling train node from population Lithuanians: 2282, original id:8178
# Dangling train node from population Lithuanians: 2045, original id:7670
# Dangling train node from population Lithuanians: 2050, original id:7680
# Dangling train node from population Lithuanians: 2078, original id:7721
# Dangling train node from population Lithuanians: 2241, original id:8108
# Dangling train node from population Lithuanians: 2231, original id:8095
# Dangling train node from population Lithuanians: 2117, original id:7791
# Dangling train node from population Lithuanians: 2026, original id:7641
# Dangling train node from population Lithuanians: 2125, original id:7801
# Dangling train node from population Lithuanians: 2138, original id:7824
# Dangling train node from population Lithuanians: 2269, original id:8157
# Dangling train node from population Lithuanians: 2267, original id:8155
# Dangling train node from population Nogais: 1332, original id:6887
# Dangling train node from population Norwegians: 3152, original id:11471
# Dangling train node from population Norwegians: 2987, original id:9107
# Dangling train node from population Norwegians: 3023, original id:9379
# Dangling train node from population Norwegians: 2996, original id:9165
# Dangling train node from population Ossetians: 5176, original id:15946
# Dangling train node from population Ossetians: 4971, original id:15578
# Dangling train node from population Tuscans: 3058, original id:10008
# Dangling train node from population Tuscans: 3087, original id:10869
# Dangling train node from population South-Italy: 3060, original id:10064
# Dangling train node from population Danes: 3072, original id:10297
# Dangling train node from population Danes: 3068, original id:10270
# Dangling train node from population Irish: 3238, original id:11877
# Dangling train node from population Russians: 6162, original id:17206
# Dangling train node from population Russians: 5793, original id:16810
# Dangling train node from population Russians: 5829, original id:16848
# Dangling train node from population Russians: 5659, original id:16666
# Dangling train node from population Russians: 3702, original id:13483
# Dangling train node from population Russians: 5380, original id:16368
# Dangling train node from population Russians: 6121, original id:17160
# Dangling train node from population Russians: 5843, original id:16863
# Dangling train node from population Russians: 6102, original id:17141
# Dangling train node from population Russians: 5458, original id:16451
# Dangling train node from population Russians: 3440, original id:13038
# Dangling train node from population Russians: 5392, original id:16381
# Dangling train node from population Russians: 5950, original id:16979
# Dangling train node from population Russians: 6181, original id:17227
# Dangling train node from population Russians: 3841, original id:13708
# Dangling train node from population Russians: 4890, original id:15438
# Dangling train node from population Russians: 6223, original id:17272
# Dangling train node from population Russians: 5432, original id:16425
# Dangling train node from population Russians: 4693, original id:15131
# Dangling train node from population Russians: 4702, original id:15148
# Dangling train node from population Russians: 5884, original id:16909
# Dangling train node from population Russians: 4205, original id:14315
# Dangling train node from population Russians: 6190, original id:17238
# Dangling train node from population Chechens: 4769, original id:15259
# Dangling train node from population Chechens: 3631, original id:13383
# Dangling train node from population Chechens: 3649, original id:13409
# Dangling train node from population Chechens: 5081, original id:15774
# Dangling train node from population Chechens: 4012, original id:14001
# Dangling train node from population Azerbaijanis,Iranians,Turks,Yazidis: 4817, original id:15325
# Dangling train node from population Poles: 5271, original id:16136
# Dangling train node from population Poles: 5285, original id:16175
# Dangling train node from population Poles: 5268, original id:16119
# Dangling train node from population Poles: 5289, original id:16187
# Dangling train node from population Poles: 5282, original id:16164
# Dangling train node from population Poles: 5290, original id:16188
# Dangling val node from population Dolgans,Yakuts: 5167, original id:15931
# Dangling val node from population Dolgans,Yakuts: 4968, original id:15574
# Dangling val node from population Buryats,Hamnigan,Mongols: 4074, original id:14107
# Dangling val node from population Kazakhs: 1154, original id:5557
# Dangling val node from population Kazakhs: 51, original id:142
# Dangling val node from population Kazakhs: 46, original id:130
# Dangling val node from population Mordvins: 1284, original id:6162
# Dangling val node from population Kabardians,Cherkess,Adygeans: 4539, original id:14869
# Dangling val node from population Kyrgyz: 3928, original id:13844
# Dangling val node from population Kyrgyz: 4960, original id:15560
# Dangling val node from population Abkhazians,Georgians,Mingrelians: 149, original id:378
# Dangling val node from population Abkhazians,Georgians,Mingrelians: 274, original id:592
# Dangling val node from population Belarusians: 3886, original id:13780
# Dangling val node from population Ukrainians: 4202, original id:14311
# Dangling val node from population Ukrainians: 6215, original id:17264
# Dangling val node from population Ukrainians: 6036, original id:17073
# Dangling val node from population Khanty,Mansi: 285, original id:621
# Dangling val node from population English: 325, original id:1529
# Dangling val node from population English: 3148, original id:11447
# Dangling val node from population English: 315, original id:1182
# Dangling val node from population English: 310, original id:948
# Dangling val node from population Ashkenazim: 5165, original id:15928
# Dangling val node from population Ashkenazim: 4596, original id:14966
# Dangling val node from population Ashkenazim: 3474, original id:13096
# Dangling val node from population Ashkenazim: 4215, original id:14327
# Dangling val node from population Ashkenazim: 4663, original id:15076
# Dangling val node from population Ashkenazim: 4063, original id:14088
# Dangling val node from population Ashkenazim: 5034, original id:15685
# Dangling val node from population Ashkenazim: 3710, original id:13496
# Dangling val node from population Swedes: 2940, original id:8880
# Dangling val node from population Swedes: 3174, original id:11539
# Dangling val node from population Swedes: 366, original id:1866
# Dangling val node from population Balkan: 2169, original id:7906
# Dangling val node from population Balkan: 1325, original id:6417
# Dangling val node from population Germans: 1222, original id:5952
# Dangling val node from population Germans: 756, original id:5100
# Dangling val node from population Germans: 1174, original id:5751
# Dangling val node from population Germans: 1179, original id:5771
# Dangling val node from population Germans: 3116, original id:11111
# Dangling val node from population Germans: 761, original id:5134
# Dangling val node from population Germans: 3138, original id:11219
# Dangling val node from population French: 464, original id:2498
# Dangling val node from population Finns: 2493, original id:8399
# Dangling val node from population Finns: 703, original id:3077
# Dangling val node from population Finns: 2613, original id:8519
# Dangling val node from population Finns: 685, original id:3059
# Dangling val node from population Albanians,Greeks: 606, original id:2910
# Dangling val node from population Ingush: 4875, original id:15406
# Dangling val node from population Lithuanians: 2288, original id:8186
# Dangling val node from population Lithuanians: 2016, original id:7620
# Dangling val node from population Lithuanians: 2022, original id:7636
# Dangling val node from population Lithuanians: 1358, original id:6958
# Dangling val node from population Lithuanians: 3345, original id:12779
# Dangling val node from population Nogais: 1333, original id:6889
# Dangling val node from population Norwegians: 2986, original id:9092
# Dangling val node from population Tuscans: 3062, original id:10138
# Dangling val node from population Danes: 3063, original id:10227
# Dangling val node from population Kalmyks: 3310, original id:12689
# Dangling val node from population Russians: 5961, original id:16990
# Dangling val node from population Russians: 5802, original id:16819
# Dangling val node from population Russians: 5526, original id:16528
# Dangling val node from population Russians: 4724, original id:15179
# Dangling val node from population Russians: 3736, original id:13540
# Dangling val node from population Poles: 5307, original id:16247
# Dangling test node from population Dolgans,Yakuts: 3515, original id:13171
# Dangling test node from population Dolgans,Yakuts: 27, original id:49
# Dangling test node from population Buryats,Hamnigan,Mongols: 3675, original id:13444
# Dangling test node from population Uzbeks: 72, original id:181
# Dangling test node from population Ket: 98, original id:247
# Dangling test node from population Kyrgyz: 3814, original id:13666
# Dangling test node from population Kyrgyz: 5028, original id:15677
# Dangling test node from population Abkhazians,Georgians,Mingrelians: 151, original id:383
# Dangling test node from population Belarusians: 3280, original id:12567
# Dangling test node from population Ukrainians: 5603, original id:16609
# Dangling test node from population Ukrainians: 3611, original id:13345
# Dangling test node from population Ukrainians: 4487, original id:14788
# Dangling test node from population Nganasan: 301, original id:713
# Dangling test node from population English: 312, original id:1053
# Dangling test node from population English: 3039, original id:9759
# Dangling test node from population English: 3142, original id:11294
# Dangling test node from population Ashkenazim: 3899, original id:13799
# Dangling test node from population Ashkenazim: 603, original id:2838
# Dangling test node from population Ashkenazim: 4127, original id:14203
# Dangling test node from population Ashkenazim: 3855, original id:13727
# Dangling test node from population Ashkenazim: 4126, original id:14201
# Dangling test node from population Ashkenazim: 4252, original id:14387
# Dangling test node from population Ashkenazim: 4450, original id:14724
# Dangling test node from population Ashkenazim: 5015, original id:15661
# Dangling test node from population Ashkenazim: 3468, original id:13086
# Dangling test node from population Ashkenazim: 3583, original id:13291
# Dangling test node from population Swedes: 3055, original id:9917
# Dangling test node from population Swedes: 3198, original id:11589
# Dangling test node from population Balkan: 2168, original id:7903
# Dangling test node from population Germans: 3136, original id:11208
# Dangling test node from population Germans: 3090, original id:11024
# Dangling test node from population Germans: 1188, original id:5826
# Dangling test node from population Germans: 1183, original id:5786
# Dangling test node from population Germans: 1205, original id:5897
# Dangling test node from population Germans: 3103, original id:11070
# Dangling test node from population Germans: 3119, original id:11120
# Dangling test node from population Germans: 3137, original id:11213
# Dangling test node from population Armenians,Hemshins: 5237, original id:16051
# Dangling test node from population Finns: 639, original id:3013
# Dangling test node from population Lithuanians: 2122, original id:7798
# Dangling test node from population Lithuanians: 2079, original id:7723
# Dangling test node from population Lithuanians: 2075, original id:7718
# Dangling test node from population Lithuanians: 2257, original id:8136
# Dangling test node from population Lithuanians: 2251, original id:8126
# Dangling test node from population Norwegians: 3154, original id:11482
# Dangling test node from population Norwegians: 2981, original id:9032
# Dangling test node from population Norwegians: 3014, original id:9313
# Dangling test node from population Ossetians: 3862, original id:13739
# Dangling test node from population Ossetians: 5169, original id:15934
# Dangling test node from population Czechs,Slovaks: 2161, original id:7889
# Dangling test node from population South-Italy: 3061, original id:10079
# Dangling test node from population Russians: 5357, original id:16345
# Dangling test node from population Russians: 5649, original id:16656
# Dangling test node from population Russians: 6041, original id:17078
# Dangling test node from population Russians: 4597, original id:14967
# Dangling test node from population Russians: 5637, original id:16644
# Dangling test node from population Russians: 5743, original id:16756
# Dangling test node from population Russians: 5815, original id:16833
# Dangling test node from population Russians: 5857, original id:16880
# Bad partition, 179:64:59 dangling nodes found, total 302
# train nodes: 3771
# val nodes: 1257
# test nodes: 1253
# features collected in 230.56367540359497 seconds
#
# Число ребер до класса: Accuracy: 0.2530, correct: 317, total: 1253
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 38>()
#      41 predictedlabels = prediction[testnodes]
#      42 title = featuredict[feature]["comment"]
# ---> 43 bh.show_prediction(testlabels, predictedlabels, labeldict.keys(), title)
#
# File ~/identityByDescent/admixfraction/baseheuristic.py:51, in show_prediction(labels, prediction, display_labels, exp_title)
#      49 acc_string = f" Accuracy: {np.sum(labels == prediction)/labels.shape[0]:.4f}, correct: {np.sum(labels == prediction)}, total: {labels.shape[0]}"
#      50 print(exp_title+":"+acc_string)
# ---> 51 print(classification_report(labels, prediction, target_names = display_labels))
#      52 cm = confusion_matrix(labels, prediction)
#      53 cm_display = ConfusionMatrixDisplay(cm, display_labels=display_labels).plot()
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2147, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2141         warnings.warn(
#    2142             "labels size, {0}, does not match size of target_names, {1}".format(
#    2143                 len(labels), len(target_names)
#    2144             )
#    2145         )
#    2146     else:
# -> 2147         raise ValueError(
#    2148             "Number of classes, {0}, does not match size of "
#    2149             "target_names, {1}. Try specifying the labels "
#    2150             "parameter".format(len(labels), len(target_names))
#    2151         )
#    2152 if target_names is None:
#    2153     target_names = ["%s" % l for l in labels]
#
# ValueError: Number of classes, 56, does not match size of target_names, 68. Try specifying the labels parameter

# %%
simplepredictions = bh.getsimplepred(featuredict)
for feature in featuredict:
    prediction = simplepredictions[feature]
    #predictedlabels = np.array([ prediction[node] for node in testnodes])
    #в тестовую выборку попали не все классы
    predictedlabels = prediction[testnodes]
    title = featuredict[feature]["comment"]
    print(labeldict)
    print (len(set(testlabels)))
    print (len(set(predictedlabels)))
    print (np.max(testlabels),np.max(predictedlabels), len(labeldict.keys()))
    bh.show_prediction(testlabels, predictedlabels, labeldict.keys(), title)
# Out:
# {'Estonians': 0, 'Dolgans,Yakuts': 1, 'Buryats,Hamnigan,Mongols': 2, 'Kazakhs': 3, 'Udmurts,Besermyan': 4, 'Uzbeks': 5, 'Tatars,Volga-Tatars,Mishar-Tatars,Kryashens': 6, 'Ket': 7, 'Mordvins': 8, 'Bashkirs': 9, 'Kabardians,Cherkess,Adygeans': 10, 'Kyrgyz': 11, 'Abkhazians,Georgians,Mingrelians': 12, 'Karelians,Veps': 13, 'Belarusians': 14, 'Ukrainians': 15, 'Chuvash': 16, 'Komi': 17, 'Moldovans': 18, 'Khanty,Mansi': 19, 'Karachays,Balkars': 20, 'Tuvans': 21, 'Nganasan': 22, 'Chelkans,Shors,Tubalar': 23, 'Evenks': 24, 'English': 25, 'Ashkenazim': 26, 'Swedes': 27, 'Balkan': 28, 'Germans': 29, 'Armenians,Hemshins': 30, 'Dagestan': 31, 'French': 32, 'Finns': 33, 'Albanians,Greeks': 34, 'Spaniards': 35, 'Hazaras': 36, 'Pashtuns': 37, 'Mozabite': 38, 'Ingush': 39, 'Jews-Iranian': 40, 'Karakalpacs': 41, 'Altaian,Altayans,Khakas,Kachins': 42, 'Kosovars': 43, 'Lithuanians': 44, 'Mexicans': 45, 'Nogais': 46, 'Norwegians': 47, 'Evens': 48, 'Ossetians': 49, 'Siberian-Tatars': 50, 'Sami': 51, 'Czechs,Slovaks': 52, 'Tuscans': 53, 'South-Italy': 54, 'Danes': 55, 'Belgium': 56, 'Irish': 57, 'Kalmyks': 58, 'Kumyks': 59, 'Mari': 60, 'Russians': 61, 'Chechens': 62, 'Azerbaijanis,Iranians,Turks,Yazidis': 63, 'Korean': 64, 'Jews-Georgian': 65, 'Jews-Azerbaijani': 66, 'Poles': 67}
# 56
# 10
# 67 60 68
# Число ребер до класса: Accuracy: 0.2530, correct: 317, total: 1253
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       9 print (len(set(predictedlabels)))
#      10 print (np.max(testlabels),np.max(predictedlabels), len(labeldict.keys()))
# ---> 11 bh.show_prediction(testlabels, predictedlabels, labeldict.keys(), title)
#
# File ~/identityByDescent/admixfraction/baseheuristic.py:51, in show_prediction(labels, prediction, display_labels, exp_title)
#      49 acc_string = f" Accuracy: {np.sum(labels == prediction)/labels.shape[0]:.4f}, correct: {np.sum(labels == prediction)}, total: {labels.shape[0]}"
#      50 print(exp_title+":"+acc_string)
# ---> 51 print(classification_report(labels, prediction, target_names = display_labels))
#      52 cm = confusion_matrix(labels, prediction)
#      53 cm_display = ConfusionMatrixDisplay(cm, display_labels=display_labels).plot()
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2147, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2141         warnings.warn(
#    2142             "labels size, {0}, does not match size of target_names, {1}".format(
#    2143                 len(labels), len(target_names)
#    2144             )
#    2145         )
#    2146     else:
# -> 2147         raise ValueError(
#    2148             "Number of classes, {0}, does not match size of "
#    2149             "target_names, {1}. Try specifying the labels "
#    2150             "parameter".format(len(labels), len(target_names))
#    2151         )
#    2152 if target_names is None:
#    2153     target_names = ["%s" % l for l in labels]
#
# ValueError: Number of classes, 56, does not match size of target_names, 68. Try specifying the labels parameter

# %% [markdown]
# # Наиболее уверенный классификатор для 20%

# %%
featureweights = {
    'IbdSumPerEdge': 0, 
    'IbdSum': 1, 
    'LongestIbd': 1, 
    'SegmentCountWMult': 0, 
    'SegmentCountPerClassize': 1, 
    'SegmentCount': 0}

#this is useful for the case where no second-best class is available, so several classifiers have infinite confidence
featurepriority = [
    "IbdSum",
    "LongestIbd",
    "SegmentCountWMult",
    "SegmentCountPerClassize",        
    "SegmentCount",    
    "IbdSumPerEdge"]

mostconfident = bh.get_most_confident_prediction(featuredict, featureweights, featurepriority)
predictedlabels = mostconfident[testnodes]
bh.show_prediction(testlabels, predictedlabels, labeldict.keys(), "Классификация наиболее уверенным классификатором.")
# Out:
# Классификация наиболее уверенным классификатором.: Accuracy: 0.8780, correct: 108, total: 123
#                              precision    recall  f1-score   support
#
#                     чеченцы       0.72      0.95      0.82        19
# кабардинцы,черкесы,адыгейцы       1.00      0.77      0.87        30
#         карачаевцы,балкарцы       0.85      1.00      0.92        17
#         дагестанские народы       1.00      0.81      0.90        27
#                      ингуши       0.83      1.00      0.91        10
#                      кумыки       1.00      0.75      0.86         4
#                     ногайцы       1.00      1.00      1.00         6
#                     осетины       0.75      0.90      0.82        10
#
#                    accuracy                           0.88       123
#                   macro avg       0.89      0.90      0.89       123
#                weighted avg       0.90      0.88      0.88       123

# %%
#search for the best parameter combination
#may take hours
featureweightrange = {
    "SegmentCount": [0],
    "SegmentCountPerClassize": [0],
    "SegmentCountWMult": [1],    
    "LongestIbd": np.arange(0.1,1.5,0.1),
    "IbdSum": np.arange(0.1,1.5,0.1),    
    "IbdSumPerEdge": [0]
}

#featureweightrange = {
#    "SegmentCount": [0],
#    "SegmentCountPerClassize": [1.38],
#    "SegmentCountWMult": [0],
#    "LongestIbd": [1],
#    "IbdSum": [0.41],
#    "IbdSumPerEdge": [0]
#}


#we will search for best weights on train nodes and then apply most confident classifier with these weights to test nodes
trainvalnodes = np.concatenate((trainnodes, valnodes))
trainvallabels = labels[trainvalnodes] 

bestweights, bestaccuracy = bh.search_best_weights(featuredict, featureweightrange, featurepriority, trainvallabels, trainvalnodes, True)
print(bestweights, bestaccuracy)

mostconfident = bh.get_most_confident_prediction(featuredict, bestweights, featurepriority)
bh.show_prediction(testlabels, mostconfident[testnodes], labeldict.keys(), "Классификация наиболее уверенным классификатором.")
#bh.show_prediction(trainlabels, mostconfident[trainnodes], labeldict.keys(), "Классификация наиболее уверенным классификатором.")
# Out:
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 0.2, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 0.30000000000000004, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8981670061099797 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.2, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.30000000000000004, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.4, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.5, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.6, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.7000000000000001, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.8, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.9, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.0, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.1, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.2000000000000002, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.3000000000000003, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 1.4000000000000001, 'LongestIbd': 1.4000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0}
# current: 0.8961303462321792 best 0.8981670061099797
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8981670061099797
# Классификация наиболее уверенным классификатором.: Accuracy: 0.8699, correct: 107, total: 123
#                              precision    recall  f1-score   support
#
#                     чеченцы       0.68      1.00      0.81        19
# кабардинцы,черкесы,адыгейцы       1.00      0.90      0.95        30
#         карачаевцы,балкарцы       0.76      0.94      0.84        17
#         дагестанские народы       1.00      0.85      0.92        27
#                      ингуши       0.89      0.80      0.84        10
#                      кумыки       1.00      0.25      0.40         4
#                     ногайцы       1.00      0.83      0.91         6
#                     осетины       0.89      0.80      0.84        10
#
#                    accuracy                           0.87       123
#                   macro avg       0.90      0.80      0.81       123
#                weighted avg       0.90      0.87      0.87       123

# %%
#repeat for new subdivision
#todo: change to f1_macro
#todo: add simple heuristics averaging
itercount = 100
totalaccr = 0
for itr in range(itercount):
    permt = bh.getrandompermutation(ncls, rng)
    #print(permt)
    trainnodeclasses, valnodeclasses, testnodeclasses = bh.dividetrainvaltest(ncls, valshare, testshare, permt)
    #here subdivision does not change translation array as we still have the same graph,
    #but will compute features only for test nodes and based on links to trainnodeclasses only

    #print("train:", trainnodeclasses)
    #print("val:", valnodeclasses)
    #print("test:", testnodeclasses)
    
    
    #when it will be neccessary to 
    #print("train|test distribution")
    #for c in trainnodeclasses:
    #    print(c, ":", trainnodeclasses[c].shape[0], ":", valnodeclasses[c].shape[0], ":", testnodeclasses[c].shape[0])

    trainnodes, valnodes, testnodes = bh.gettrainvaltestnodes(trainnodeclasses, valnodeclasses, testnodeclasses)
    #print("train nodes:", trainnodes.shape[0])
    #print("test nodes:", testnodes.shape[0])
    trainvalnodes = np.concatenate((trainnodes,valnodes))

    testlabels = labels[testnodes]
    trainvallabels = labels[trainvalnodes] 

    start = time.time()
    featuredict = bh.getfeatures(grph, grph.nodes, trainnodeclasses, labeldict, pairs, trns )
    #print(f"features collected in {time.time()-start} seconds\n")

    bestweights, bestaccuracy = bh.search_best_weights(featuredict, featureweightrange, featurepriority, trainvallabels, trainvalnodes, False)
    print("iter", itr)
    print(bestweights, bestaccuracy)
    mostconfident = bh.get_most_confident_prediction(featuredict, bestweights, featurepriority)
    accr = np.sum(testlabels == mostconfident[testnodes])/testnodes.shape[0]
    totalaccr += accr
    print(f" Accuracy: {accr:.4f}, correct: {np.sum(testlabels == mostconfident[testnodes])}, total: {testnodes.shape[0]}")
    
    #bh.show_prediction(testlabels, mostconfident[testnodes], labeldict.keys(), "Классификация наиболее уверенным классификатором.")
    #break
print("average accuracy:", totalaccr/itercount)
# Out:
# iter 0
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8920570264765784
#  Accuracy: 0.8699, correct: 107, total: 123
# iter 1
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8940936863543788
#  Accuracy: 0.9106, correct: 112, total: 123
# iter 2
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9103869653767821
#  Accuracy: 0.9187, correct: 113, total: 123
# iter 3
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9144602851323829
#  Accuracy: 0.8374, correct: 103, total: 123
# iter 4
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9022403258655805
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 5
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8981670061099797
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 6
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9022403258655805
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 7
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.90020366598778
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 8
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.879837067209776
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 9
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8981670061099797
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 10
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8961303462321792
#  Accuracy: 0.8780, correct: 108, total: 123
# iter 11
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8879837067209776
#  Accuracy: 0.8618, correct: 106, total: 123
# iter 12
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8920570264765784
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 13
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8615071283095723
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 14
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9063136456211812
#  Accuracy: 0.9106, correct: 112, total: 123
# iter 15
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.4, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8981670061099797
#  Accuracy: 0.8618, correct: 106, total: 123
# iter 16
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9063136456211812
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 17
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.879837067209776
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 18
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8818737270875764
#  Accuracy: 0.9106, correct: 112, total: 123
# iter 19
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9103869653767821
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 20
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9042769857433809
#  Accuracy: 0.8780, correct: 108, total: 123
# iter 21
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8859470468431772
#  Accuracy: 0.9431, correct: 116, total: 123
# iter 22
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9063136456211812
#  Accuracy: 0.8537, correct: 105, total: 123
# iter 23
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9124236252545825
#  Accuracy: 0.8699, correct: 107, total: 123
# iter 24
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9307535641547862
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 25
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9103869653767821
#  Accuracy: 0.8780, correct: 108, total: 123
# iter 26
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8920570264765784
#  Accuracy: 0.9431, correct: 116, total: 123
# iter 27
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8859470468431772
#  Accuracy: 0.8537, correct: 105, total: 123
# iter 28
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8839103869653768
#  Accuracy: 0.9593, correct: 118, total: 123
# iter 29
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8920570264765784
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 30
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9144602851323829
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 31
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9103869653767821
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 32
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.890020366598778
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 33
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.879837067209776
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 34
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.879837067209776
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 35
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8655804480651731
#  Accuracy: 0.9431, correct: 116, total: 123
# iter 36
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9144602851323829
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 37
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.869653767820774
#  Accuracy: 0.9106, correct: 112, total: 123
# iter 38
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9083503054989817
#  Accuracy: 0.8618, correct: 106, total: 123
# iter 39
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.924643584521385
#  Accuracy: 0.8537, correct: 105, total: 123
# iter 40
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8961303462321792
#  Accuracy: 0.9187, correct: 113, total: 123
# iter 41
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.90020366598778
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 42
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8940936863543788
#  Accuracy: 0.8618, correct: 106, total: 123
# iter 43
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.879837067209776
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 44
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9226069246435845
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 45
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.3000000000000003, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.879837067209776
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 46
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9144602851323829
#  Accuracy: 0.8618, correct: 106, total: 123
# iter 47
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8839103869653768
#  Accuracy: 0.9106, correct: 112, total: 123
# iter 48
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8961303462321792
#  Accuracy: 0.8618, correct: 106, total: 123
# iter 49
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8778004073319755
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 50
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.924643584521385
#  Accuracy: 0.9187, correct: 113, total: 123
# iter 51
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8879837067209776
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 52
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9042769857433809
#  Accuracy: 0.8699, correct: 107, total: 123
# iter 53
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8818737270875764
#  Accuracy: 0.8780, correct: 108, total: 123
# iter 54
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9144602851323829
#  Accuracy: 0.8618, correct: 106, total: 123
# iter 55
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8920570264765784
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 56
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9164969450101833
#  Accuracy: 0.8780, correct: 108, total: 123
# iter 57
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9042769857433809
#  Accuracy: 0.8699, correct: 107, total: 123
# iter 58
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9042769857433809
#  Accuracy: 0.9268, correct: 114, total: 123
# iter 59
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8940936863543788
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 60
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8778004073319755
#  Accuracy: 0.8780, correct: 108, total: 123
# iter 61
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8961303462321792
#  Accuracy: 0.9268, correct: 114, total: 123
# iter 62
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.90020366598778
#  Accuracy: 0.8780, correct: 108, total: 123
# iter 63
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8961303462321792
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 64
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9042769857433809
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 65
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8839103869653768
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 66
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8981670061099797
#  Accuracy: 0.9268, correct: 114, total: 123
# iter 67
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8920570264765784
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 68
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8737270875763747
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 69
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8859470468431772
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 70
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9022403258655805
#  Accuracy: 0.8699, correct: 107, total: 123
# iter 71
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8940936863543788
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 72
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8859470468431772
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 73
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.890020366598778
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 74
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.90020366598778
#  Accuracy: 0.9106, correct: 112, total: 123
# iter 75
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9185336048879837
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 76
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9144602851323829
#  Accuracy: 0.8699, correct: 107, total: 123
# iter 77
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8879837067209776
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 78
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.0, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8839103869653768
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 79
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8879837067209776
#  Accuracy: 0.9187, correct: 113, total: 123
# iter 80
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.890020366598778
#  Accuracy: 0.9187, correct: 113, total: 123
# iter 81
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8716904276985743
#  Accuracy: 0.8699, correct: 107, total: 123
# iter 82
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.8, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9205702647657841
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 83
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9124236252545825
#  Accuracy: 0.8699, correct: 107, total: 123
# iter 84
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 1.2000000000000002, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9063136456211812
#  Accuracy: 0.9187, correct: 113, total: 123
# iter 85
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9063136456211812
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 86
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8879837067209776
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 87
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.90020366598778
#  Accuracy: 0.9268, correct: 114, total: 123
# iter 88
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9022403258655805
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 89
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9022403258655805
#  Accuracy: 0.9187, correct: 113, total: 123
# iter 90
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.879837067209776
#  Accuracy: 0.8699, correct: 107, total: 123
# iter 91
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.90020366598778
#  Accuracy: 0.9187, correct: 113, total: 123
# iter 92
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9164969450101833
#  Accuracy: 0.8943, correct: 110, total: 123
# iter 93
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.6, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8961303462321792
#  Accuracy: 0.9512, correct: 117, total: 123
# iter 94
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8981670061099797
#  Accuracy: 0.8862, correct: 109, total: 123
# iter 95
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8981670061099797
#  Accuracy: 0.9268, correct: 114, total: 123
# iter 96
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.7000000000000001, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8818737270875764
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 97
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.5, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.890020366598778
#  Accuracy: 0.9024, correct: 111, total: 123
# iter 98
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.1, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.8940936863543788
#  Accuracy: 0.8537, correct: 105, total: 123
# iter 99
# {'IbdSumPerEdge': 0, 'IbdSum': 0.1, 'LongestIbd': 0.9, 'SegmentCountWMult': 1, 'SegmentCountPerClassize': 0, 'SegmentCount': 0} 0.9042769857433809
#  Accuracy: 0.8537, correct: 105, total: 123
# average accuracy: 0.8938211382113826
