# %%
import ancinf
from ancinf.utils.visualize import visualize_classifier_data, load_data_from_file

orig_data = load_data_from_file("/home/ashmelev/ancestry-inference/test/workdir/test6_tmp/origweights_s0-10.results")
visualize_classifier_data(orig_data, sort_bars=True, annotate=True)

orig_data = load_data_from_file("/home/ashmelev/ancestry-inference/test/workdir/test6_tmp/4ds-community.result")
visualize_classifier_data(orig_data, sort_bars=True, annotate=True)
